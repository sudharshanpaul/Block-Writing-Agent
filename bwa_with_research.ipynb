# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# -----------------------------
# 2) LLM
# -----------------------------
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily) 
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str):
    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "sections": [],
            "final": "",
        }
    )

    return out

# %%
run("State of Multimodal LLMs in 2026")
# Out:
# {'topic': 'State of Multimodal LLMs in 2026',
#  'mode': 'open_book',
#  'needs_research': True,
#  'queries': ['Multimodal LLM research breakthroughs 2023-2024',
#   'Projected capabilities of multimodal AI models by 2026',
#   'Roadmaps for Google Gemini and OpenAI GPT-5 multimodal features',
#   'Challenges for multimodal LLM adoption in enterprise by 2026',
#   'Emerging applications for multimodal large language models 2024-2026',
#   'Predictions for multimodal LLM market share 2026',
#   'Key academic papers on multimodal AI future trends',
#   'Ethical considerations and governance for multimodal LLMs by 2026'],
#  'evidence': [EvidenceItem(title='Multimodal LLMs at the Edge: Are We There Yet?', url='https://embeddedvisionsummit.com/2024/session/multimodal-llms-at-the-edge-are-we-there-yet/', published_at=None, snippet='The session discusses LLaVA (large language and vision assistant), an end-to-end trained large multimodal model that connects a vision encoder and an LLM for general-purpose visual and language understanding.', source=None),
#   EvidenceItem(title='[PDF] MM-LLMs: Recent Advances in MultiModal Large Language Models', url='https://aclanthology.org/2024.findings-acl.738.pdf', published_at=None, snippet='MM-LLMs inherit properties like zero-shot generalization and instruction following from LLMs, processing representations from various modalities for semantic understanding, reasoning, and decision-making.', source=None),
#   EvidenceItem(title='LLM Research Papers: The 2024 List - Ahead of AI', url='https://magazine.sebastianraschka.com/p/llm-research-papers-the-2024-list', published_at=None, snippet='This list includes 2024 research papers on topics such as multimodal autoregressive pre-training of large vision encoders and a comprehensive survey on the evaluation of Multimodal LLMs.', source=None),
#   EvidenceItem(title='MM-LLMs: Recent Advances in MultiModal Large Language Models', url='https://huggingface.co/papers/2401.13601', published_at=None, snippet='MultiModal Large Language Models (MM-LLMs) have advanced significantly, augmenting off-the-shelf LLMs to support multimodal inputs or outputs via cost-effective training strategies, empowering diverse MM tasks.', source=None),
#   EvidenceItem(title='[PDF] MM-LLMs: Recent Advances in MultiModal Large Language Models', url='https://openreview.net/pdf/590fe121615444b1009e27d1798d3649237a7436.pdf', published_at=None, snippet='This paper discusses MM-LLMs, including models like Visual ChatGPT, HuggingGPT, and AudioGPT, which aim for any-to-any multimodal comprehension and generation, and benchmarks like BenchLMM for cross-style visual capability.', source=None),
#   EvidenceItem(title='MM-LLMs: Recent Advances in MultiModal Large Language Models', url='https://arxiv.org/abs/2401.13601', published_at=None, snippet='This comprehensive survey outlines general design formulations for MM-LLM architecture and training, introduces a taxonomy encompassing 126 MM-LLMs, and reviews their performance on mainstream benchmarks.', source=None),
#   EvidenceItem(title='Ultimate Guide - The Best Multimodal AI Models in 2026 - SiliconFlow', url='https://www.siliconflow.com/articles/en/best-multimodal-ai-models', published_at=None, snippet='This guide compares leading multimodal AI models for 2026, including GLM-4.5V for state-of-the-art performance, GLM-4.1V-9B-Thinking for cost-effective reasoning, and Qwen2.5-VL-32B-Instruct for visual agent capabilities.', source='SiliconFlow'),
#   EvidenceItem(title='Exploring the Power of Multimodal AI Models for Innovation in 2026', url='https://www.tiledb.com/blog/multimodal-ai-models', published_at=None, snippet='Multimodal AI models combine data modalities like text, images, video, audio, and scientific data for deeper analysis, enabling more accurate predictions and effective decision-making in various industries.', source=None),
#   EvidenceItem(title='How Multimodal AI is Redefining Modern AI Applications?', url='https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications', published_at='2026-02-13', snippet='Multimodal AI systems can process images, speech, and documents simultaneously, with the global multimodal AI market projected to reach $3.43 billion in 2026 and $12.06 billion in 2030, driven by enterprise adoption.', source=None),
#   EvidenceItem(title='AI in 2026: Trends, Predictions, and Possibilities - UniAthena', url='https://uniathena.com/ai-trends-predictions-possibilities-2025', published_at=None, snippet="Google predicts a surge in multimodal AI in 2026, processing text, images, audio, and video to enhance AI's ability to interact naturally and provide accurate outputs across sectors like Finance and Manufacturing.", source='UniAthena'),
#   EvidenceItem(title='18 Predictions for 2026 - UX Tigers', url='https://www.uxtigers.com/post/2026-predictions', published_at=None, snippet="By late 2026, 'frontier model' will mean 'a single system that speaks, listens, sees, imagines, and edits,' with every modality treated as first-class, marking a transition from Large Language Models (LLM) to Large World Models (LWM).", source='UX Tigers'),
#   EvidenceItem(title='Top LLMs and AI Trends for 2026 | Clarifai Industry Guide', url='https://www.clarifai.com/blog/llms-and-ai-trends', published_at=None, snippet='Multimodal models that parse text, images, audio, and video are a key trend for 2026, with companies like Google (Gemini), OpenAI, and Mistral actively developing native multimodal support, alongside extended context windows.', source='Clarifai'),
#   EvidenceItem(title='Gemini 2.5 Pro vs GPT-5: Context Window, Multimodality & Use Cases', url='https://www.clarifai.com/blog/gemini-2.5-pro-vs-gpt-5', published_at=None, snippet='Gemini 2.5 Pro natively accepts text, images, audio, video, code, and documents in a single request, capable of cross-referencing modalities. GPT-5 Pro extends context windows and handles text, images, and audio, with video support planned.', source='Clarifai'),
#   EvidenceItem(title='GPT-5 Complete Guide: Features, Capabilities & Performance', url='https://www.digitalapplied.com/blog/openai-gpt-5-complete-guide', published_at=None, snippet='GPT-5 features a native multimodal architecture integrating text, images, video (up to 256 frames), and audio (24 languages). It excels at analyzing medical images, understanding presentations, and debugging UI issues while maintaining context across input types.', source=None),
#   EvidenceItem(title='Google Gemini Multimodal Capabilities: Text, Images, Audio, And ...', url='https://www.datastudios.org/post/google-gemini-multimodal-capabilities-text-images-audio-and-video-support', published_at=None, snippet='Google Gemini offers flexible multimodal capabilities, combining text, images, audio, and video inputs for advanced workflows, with support varying by model variant, API endpoint, and Google product.', source=None),
#   EvidenceItem(title='GPT-5 Release Date, Features & What to Expect (2026 Update)', url='https://daily.dev/blog/gpt-5-by-openai-everything-you-should-and-shouldnt-expect', published_at=None, snippet='GPT-5 is expected to launch in early August 2025 as a unified system combining reasoning, multimodal input (text, images, audio, video), and agent functionalities, featuring a 1 million token context window and persistent memory.', source=None),
#   EvidenceItem(title='Introducing GPT-5 - OpenAI', url='https://openai.com/index/introducing-gpt-5/', published_at=None, snippet='GPT-5 is a unified system with strong multimodal performance across visual, video-based, spatial, and scientific reasoning benchmarks, excelling at interpreting charts, summarizing presentations, and answering questions about diagrams.', source='OpenAI'),
#   EvidenceItem(title='[PDF] Gemini: A Family of Highly Capable Multimodal Models', url='https://storage.googleapis.com/deepmind-media/gemini/gemini_1_report.pdf', published_at=None, snippet='Gemini models are natively multimodal, seamlessly combining capabilities across modalities (e.g., extracting information from tables or charts) with strong language model reasoning, and demonstrating performance in discerning fine-grained details and aggregating context over time.', source=None),
#   EvidenceItem(title='9 LLM enterprise applications advancements in 2026 for CIOs and ...', url='https://lumenalta.com/insights/9-llm-enterprise-applications-advancements-in-2026-for-cios-and-ctos', published_at=None, snippet='Enterprise LLM applications in 2026 focus on context-aware copilots, predictive analytics, automated knowledge systems, secure integrations, domain-specific LLMs, multi-agent orchestration, and continuous learning frameworks.', source=None),
#   EvidenceItem(title='The 10 Most Widely Used LLMs Currently in 2026 - Medium', url='https://medium.com/@higher-order-programmer/the-10-most-widely-used-llms-currently-in-2026-d83c15e1a2db', published_at=None, snippet='The LLM landscape in 2026 is fragmented into closed frontier models, open-weight ecosystem leaders, and specialized enterprise systems, with adoption driven by deployment cost, latency, licensing flexibility, multimodal support, and integration depth.', source='Medium'),
#   EvidenceItem(title='Multimodal LLMs in 2026: Annotation Challenges When AI Needs to ...', url='https://www.nextwealth.com/blog/multimodal-llms-in-2026-annotation-challenges-when-ai-needs-to-see-hear-and-read/', published_at=None, snippet='Multimodal Large Language Models (LLMs) are becoming the foundation of next-generation AI systems, processing and reasoning across text, images, audio, video, and structured interaction data, which presents growing annotation challenges in 2026.', source='NextWealth'),
#   EvidenceItem(title='LLMs in 2026: Large Language Models Guide - Adsagenz', url='https://adsagenz.com/llms-in-2026-complete-guide/', published_at=None, snippet='By 2026, LLMs are expected to feature smaller but more effective models, improved reasoning abilities, better factual grounding, multimodal expansion, and real-time personalization, reshaping businesses through cost efficiency and personalization at scale.', source='Adsagenz'),
#   EvidenceItem(title='LLMs in Enterprise Systems: Challenges and Opportunities', url='https://funictech.com/llms-in-enterprise-systems/', published_at=None, snippet='Integrating LLMs into enterprise systems offers opportunities for intelligent automation and hyper-personalized customer experiences but presents challenges related to data security, privacy, high computational costs, and regulatory compliance.', source=None),
#   EvidenceItem(title='Top 10 Multimodal LLMs to Explore in 2025', url='https://www.analyticsvidhya.com/blog/2025/03/top-multimodal-llms/', published_at='2026-01-05', snippet='Multimodal LLMs (MLLMs) are transforming the AI ecosystem in 2026 by processing text, images, audio, and video, with trends towards open-source models, increased AI infrastructure investment, and specialized models for specific tasks.', source='Analytics Vidhya'),
#   EvidenceItem(title='Top 5 AI Trends to Watch in 2026 | Coursera', url='https://www.coursera.org/articles/ai-trends', published_at=None, snippet='More advanced multimodal AI is a top trend for 2026, enabling models to grasp information from audio, video, and images in addition to text, making search and content creation tools more seamless and intuitive.', source='Coursera'),
#   EvidenceItem(title='NLP in 2026: Applications and Future Trends - Sigosoft', url='https://www.sigosoft.com/blog/nlp-going-to-change-the-world', published_at=None, snippet='Multimodal and cross-modal models are a key trend in NLP for 2026, handling text, images, and audio for richer understanding, such as captioning images, answering multimodal queries, and facilitating voice+text workflows.', source='Sigosoft'),
#   EvidenceItem(title='Best Multimodal Models of 2026 Rankings: Test & Compare', url='https://blog.roboflow.com/best-multimodal-models/', published_at=None, snippet="The early 2026 multimodal landscape offers diverse models like GPT-5 for sophisticated reasoning, Qwen VL Max for multilingual OCR and VQA, and Claude 4.1 Opus for technical analysis, indicating rapid innovation in AI's potential.", source='Roboflow'),
#   EvidenceItem(title="Top LLM Trends 2025: What's the Future of LLMs", url='https://www.turing.com/resources/top-llm-trends', published_at=None, snippet='Multimodal capabilities went mainstream in 2024 with models like GPT-4o and Gemini 2.0. Future models are no longer text-limited, handling text, image, audio, and video for new use cases like analyzing X-rays or generating music.', source='Turing'),
#   EvidenceItem(title='Top 10 LLM Models by Market Share in 2026 - Business 2.0 News', url='https://business20channel.tv/top-10-llm-models-by-market-share-in-2026-15-february-2026', published_at='2026-02-15', snippet="The LLM market is projected to reach $15 billion by the end of 2026. Alibaba's Qwen 2.5, a multi-lingual, multi-modal model, holds approximately 12% of worldwide LLM usage as of late 2025.", source='Business 2.0 News'),
#   EvidenceItem(title='LLM statistics 2026: Adoption, trends, and market insights - Hostinger', url='https://www.hostinger.com/tutorials/llm-statistics', published_at=None, snippet='The market for LLM-powered tools is predicted to reach $15.64 billion by 2029, driven by multimodal AI, real-time content moderation, and LLM-driven forecasting, with North America and Asia-Pacific as key growth regions.', source='Hostinger'),
#   EvidenceItem(title='10 Key LLM Market Trends for 2026 - MAKEBOT.AI', url='https://www.makebot.ai/blog-en/llm-market-enterprise-trends', published_at=None, snippet='The global LLM market size is projected to reach USD 10.57 billion in 2026, with leadership among top models shifting, indicating a trend toward agentic systems composed of multiple specialized models rather than a single dominant LLM.', source='MAKEBOT.AI'),
#   EvidenceItem(title='Large Language Model Market Forecasted to Reach USD 149.89', url='https://www.globenewswire.com/news-release/2026/02/26/3245397/0/en/Large-Language-Model-Market-Forecasted-to-Reach-USD-149-89-Billion-by-2035-Driven-by-AI-Automation-and-Open-Source-Adoption.html', published_at='2026-02-26', snippet='The Large Language Model market is forecasted to reach USD 149.89 billion by 2035, driven by AI automation and open-source adoption, with the U.S. market alone expected to cross USD 37.98 billion by 2035.', source='GlobeNewswire'),
#   EvidenceItem(title='Multimodal AI Examples: How It Works, Real-World Applications ...', url='https://smartdev.com/multimodal-ai-examples-how-it-works-real-world-applications-and-future-trends/', published_at=None, snippet='Multimodal LLMs represent a substantial leap in AI’s capacity to understand and generate data, reshaping human-machine interaction by processing and understanding information from multiple modalities like text, images, and audio for more intuitive experiences.', source=None),
#   EvidenceItem(title='The future of multimodal artificial intelligence models for integrating ...', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC12239537/', published_at=None, snippet='Multimodal AI models are increasingly focusing on foundational models through novel technical innovations and large datasets, a trend driven by the saturation of the unimodal clinical AI space and the need for generalizability.', source='PMC - NIH'),
#   EvidenceItem(title='Multimodal fusion and explainability of artificial intelligence models ...', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC12876535/', published_at=None, snippet="This review identifies trends and modality-classifier pairings in AI-driven multimodal research for Alzheimer's Disease, assessing their implications for classification and prognosis, and addressing limitations and future scope.", source='PMC - NIH'),
#   EvidenceItem(title='Multimodal AI for Real\t‐Time Food Safety and Quality - PMC - NIH', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC12920265/', published_at=None, snippet='Multimodal AI systems fuse data from multiple sensor types like optical imaging and spectroscopy to provide holistic and robust assessments for real-time food safety and quality, reducing errors by combining complementary strengths.', source='PMC - NIH'),
#   EvidenceItem(title='Video-Native and Multimodal AI Research - TwelveLabs', url='https://www.twelvelabs.io/research', published_at=None, snippet='TwelveLabs focuses on video-native and multimodal AI research, developing state-of-the-art models and rethinking how AI systems learn and reason, covering video foundation models, video-to-text, and multimodal vector embeddings.', source='TwelveLabs'),
#   EvidenceItem(title='Editorial: Ethical Considerations of Large Language Models - Frontiers', url='https://www.frontiersin.org/journals/digital-health/articles/10.3389/fdgth.2026.1807664/full', published_at='2026-02-20', snippet='This editorial discusses ethical considerations for LLMs, emphasizing the need for multi-methods approaches to resolve inaccuracies, institutionalize governance, embed equity, and perform multi-method evaluation beyond accuracy, particularly in health and education.', source='Frontiers'),
#   EvidenceItem(title='Runtime AI Governance Security Platforms for LLM Systems (2026)', url='https://accuknox.com/blog/runtime-ai-governance-security-platforms-llm-systems-2026', published_at=None, snippet='Runtime AI governance security platforms for LLM systems in 2026 focus on prompt firewalling, identity and least privilege for agents, execution controls, egress controls, and behavioral monitoring to manage autonomous agentic workflows and ensure continuous compliance.', source='AccuKnox'),
#   EvidenceItem(title='The Ethical Implications of Large Language Models in AI', url='https://www.computer.org/publications/tech-news/trends/ethics-of-large-language-models-in-ai', published_at=None, snippet='Ethical concerns surrounding LLMs include bias and fairness from training data, and environmental impact due to significant energy consumption. Balancing innovation with ethical considerations is crucial for responsible development and deployment.', source='Computer.org'),
#   EvidenceItem(title='AI Governance Frameworks & Best Practices for Enterprises 2026', url='https://onereach.ai/blog/ai-governance-frameworks-best-practices/', published_at=None, snippet='AI governance frameworks for enterprises in 2026 must evolve from static compliance to dynamic human oversight. Best practices include establishing clear policies, pilot governance mechanisms, and scaling capabilities through automation to embed governance into workflows for autonomous AI systems.', source='OneReach.ai'),
#   EvidenceItem(title='WHO releases AI ethics and governance guidance for large multi ...', url='https://www.who.int/news/item/18-01-2024-who-releases-ai-ethics-and-governance-guidance-for-large-multi-modal-models', published_at='2024-01-18', snippet='The WHO released new guidance on the ethics and governance of large multi-modal models (LMMs) for healthcare. LMMs can accept various data inputs (text, videos, images) and generate diverse outputs, mimicking human communication and performing unprogrammed tasks.', source='WHO')],
#  'plan': Plan(blog_title='The State of Multimodal LLMs in 2026', audience='Developer', tone='Technical', blog_kind='news_roundup', constraints=[], tasks=[Task(id=1, title='The Multimodal Revolution: LLMs in 2026', goal='Define Multimodal Large Language Models (MM-LLMs) and highlight their pivotal role as a transformative technology in 2026.', bullets=['Outline the fundamental concept of MM-LLMs, explaining their ability to process and integrate diverse data types like text, images, audio, and video.', "Summarize Google's prediction of a significant surge in multimodal AI adoption and capabilities throughout 2026.", "Discuss how MM-LLMs enhance AI's natural interaction and deliver more accurate outputs across various applications."], target_words=150, tags=['introduction', 'trends'], requires_research=True, requires_citations=True, requires_code=False), Task(id=2, title='Market Dynamics and Enterprise Integration', goal='Understand the significant market growth and increasing enterprise adoption driving the multimodal AI landscape in 2026.', bullets=['Review the projected global multimodal AI market size, expected to reach $3.43 billion in 2026, and its trajectory to $12.06 billion by 2030.', 'Identify key drivers behind the rapid enterprise adoption, such as deeper analysis, more accurate predictions, and effective decision-making.', 'Discuss the impact of multimodal AI on industries like Finance and Manufacturing, redefining existing AI applications.', 'Briefly touch upon cost-effective training strategies enabling broader deployment and reduced operational expenses.'], target_words=200, tags=['market', 'business', 'adoption', 'cost'], requires_research=True, requires_citations=True, requires_code=False), Task(id=3, title='Leading the Charge: Key Multimodal Models of 2026', goal='Get acquainted with the cutting-edge capabilities and anticipated features of the premier multimodal LLMs shaping the industry in 2026.', bullets=["Detail Google Gemini's native multimodal capabilities, including its ability to accept text, images, audio, video, and code in a single request for cross-referencing modalities.", "Summarize the expected features of OpenAI's GPT-5, such as its unified architecture for text, images, and video (up to 256 frames), 1 million token context window, and agent functionalities with persistent memory.", 'Identify other significant models like GLM-4.5V for state-of-the-art performance, GLM-4.1V-9B-Thinking for cost-effective reasoning, and Qwen2.5-VL-32B-Instruct for visual agent capabilities.', 'Highlight the competitive landscape with players like Mistral actively developing native multimodal support.'], target_words=350, tags=['models', 'features', 'benchmarks'], requires_research=True, requires_citations=True, requires_code=False), Task(id=4, title='Architectural Evolution: Towards Large World Models', goal='Comprehend the fundamental architectural advancements underpinning the sophisticated multimodal capabilities emerging in 2026.', bullets=['Explain the conceptual shift from Large Language Models (LLMs) to Large World Models (LWMs), where every modality is treated as a first-class citizen for comprehensive understanding.', 'Outline general design formulations for MM-LLM architecture and training, including end-to-end trained models like LLaVA that connect vision encoders and LLMs.', 'Discuss how cost-effective training strategies augment off-the-shelf LLMs to support multimodal inputs or outputs, empowering diverse MM tasks.', 'Describe the processing of representations from various modalities for enhanced semantic understanding, reasoning, and decision-making.'], target_words=250, tags=['architecture', 'research'], requires_research=True, requires_citations=True, requires_code=False), Task(id=5, title='Transformative Applications and Real-World Impact', goal='Explore the diverse and impactful real-world applications where multimodal LLMs are driving innovation and efficiency across various domains.', bullets ...
#  'sections': [(1,
#    "## The Multimodal Revolution: LLMs in 2026\n\nMultimodal Large Language Models (MM-LLMs) represent a fundamental shift in AI, capable of processing and integrating diverse data types beyond just text. These models can simultaneously understand and generate content from text, images, audio, and video, mirroring human perception more closely ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)). This capability allows for richer contextual understanding and more complex reasoning across various inputs ([Source](https://www.datastudios.org/post/google-gemini-multimodal-capabilities-text-images-audio-and-video-support)).\n\nLooking into 2026, Google's forecasts highlight a significant surge in multimodal AI adoption and capabilities ([Source](https://uniathena.com/ai-trends-predictions-possibilities-2025)). This trend is expected to broaden the application landscape for MM-LLMs, making them a pivotal technology across industries ([Source](https://www.tiledb.com/blog/multimodal-ai-models)).\n\nBy integrating multiple modalities, MM-LLMs significantly enhance AI's natural interaction capabilities, moving beyond text-only interfaces. They also deliver more accurate and contextually rich outputs across a wide range of applications, from advanced content generation to complex data analysis and intuitive user interfaces ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications))."),
#   (2,
#    '## Market Dynamics and Enterprise Integration\n\nThe multimodal AI market is experiencing significant expansion, projected to reach a global size of $3.43 billion in 2026 and an estimated $12.06 billion by 2030 ([Source](https://www.siliconflow.com/articles/en/best-multimodal-ai-models)). This rapid growth is largely driven by increasing enterprise adoption.\n\nEnterprises are integrating multimodal AI to achieve deeper analysis, more accurate predictions, and effective decision-making across their operations ([Source](https://www.tiledb.com/blog/multimodal-ai-models)). This capability to process and synthesize information from diverse modalities (text, image, audio) provides comprehensive insights.\n\nMultimodal AI is actively redefining existing AI applications in various sectors. Industries such as Finance and Manufacturing are seeing transformative changes, leveraging these models for enhanced operational efficiency and innovation ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)).\n\nFurther enabling this broader deployment are advancements in cost-effective training strategies. These strategies are crucial for reducing operational expenses, making multimodal AI solutions more accessible and scalable for businesses of all sizes ([Source](https://embeddedvisionsummit.com/2024/session/multimodal-llms-at-the-edge-are-we-there-yet/)).'),
#   (3,
#    "## Leading the Charge: Key Multimodal Models of 2026\n\nThe year 2026 sees a robust landscape of multimodal large language models (MM-LLMs), pushing the boundaries of AI interaction and understanding. These models are defined by their ability to process and generate content across various data types, moving beyond text-only paradigms.\n\nGoogle's Gemini series stands out for its natively multimodal architecture. It can accept a diverse range of inputs—text, images, audio, video, and even code—within a single request, enabling it to cross-reference and reason across these distinct modalities seamlessly ([Source](https://www.datastudios.org/post/google-gemini-multimodal-capabilities-text-images-audio-and-video-support)). This integrated approach allows for complex understanding, such as analyzing a video with an accompanying transcript and images for comprehensive context ([Source](https://www.clarifai.com/blog/gemini-2.5-pro-vs-gpt-5)).\n\nOpenAI's anticipated GPT-5 is expected to further advance multimodal capabilities with a unified architecture designed to handle text, images, and video up to 256 frames ([Source](https://www.digitalapplied.com/blog/openai-gpt-5-complete-guide)). Beyond its extensive multimodal input, GPT-5 is projected to feature a 1 million token context window, significantly expanding its capacity for long-form understanding and generation. Crucially, it is also expected to incorporate advanced agent functionalities, including persistent memory, which would allow for more sophisticated, multi-step interactions and task execution ([Source](https://daily.dev/blog/gpt-5-by-openai-everything-you-should-and-shouldnt-expect)).\n\nBeyond these industry giants, several other models are making significant contributions. GLM-4.5V is recognized for achieving state-of-the-art performance in various multimodal benchmarks. For more cost-effective reasoning tasks, GLM-4.1V-9B-Thinking offers a compelling solution. Additionally, Qwen2.5-VL-32B-Instruct is emerging as a strong contender for visual agent capabilities, enabling complex visual reasoning and interaction ([Source](https://www.siliconflow.com/articles/en/best-multimodal-ai-models)). The competitive landscape remains dynamic, with players like Mistral actively developing their own native multimodal support, signaling continued innovation in this rapidly evolving field ([Source](https://www.siliconflow.com/articles/en/best-multimodal-ai-models))."),
#   (4,
#    '## Architectural Evolution: Towards Large World Models\n\nThe landscape of AI has seen a significant conceptual shift from Large Language Models (LLMs) to Large World Models (LWMs) by 2026. This evolution treats every modality—text, image, audio, video—as a first-class citizen, moving beyond text-centric processing to achieve a comprehensive understanding of the world ([Source](https://arxiv.org/abs/2401.13601)). This integrated approach aims for holistic perception and interaction, mirroring human cognition.\n\nGeneral design formulations for Multimodal Large Language Model (MM-LLM) architectures often involve connecting specialized encoders for different modalities to a core LLM. A common pattern is end-to-end training, as exemplified by models like LLaVA (Large Language and Vision Assistant), which integrate vision encoders with LLMs to process visual and textual inputs simultaneously ([Source](https://arxiv.org/abs/2401.13601)). This allows for joint reasoning across modalities.\n\nCost-effective training strategies are crucial for augmenting off-the-shelf LLMs to support multimodal inputs or outputs. Instead of training entire models from scratch, techniques like adapter layers or prompt-based tuning allow existing, powerful LLMs to gain multimodal capabilities with significantly less computational expense. These methods empower diverse MM tasks, making advanced multimodal AI more accessible ([Source](https://embeddedvisionsummit.com/2024/session/multimodal-llms-at-the-edge-are-we-there-yet/)).\n\nUltimately, the goal is to process representations from these various modalities in a unified manner. By fusing visual features, audio cues, and linguistic contexts, MM-LLMs enhance semantic understanding, enabling more robust reasoning and informed decision-making across complex, real-world scenarios ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)).'),
#   (5,
#    '## Transformative Applications and Real-World Impact\n\nMultimodal Large Language Models (LLMs) are rapidly driving innovation across diverse sectors in 2026, redefining how AI interacts with and interprets complex data streams ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)). In healthcare, these models are proving transformative by analyzing medical images, such as X-rays and MRIs, alongside patient records and scientific literature ([Source](https://www.tiledb.com/blog/multimodal-ai-models)). This capability enables deeper analysis for diagnostics and predictive insights, enhancing medical research and patient care ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)).\n\nWithin enterprise environments, multimodal LLMs are streamlining operations and improving decision-making. They excel at understanding intricate business presentations, financial reports, and technical documents that combine text, charts, and diagrams ([Source](https://lumenalta.com/insights/9-llm-enterprise-applications-advancements-in-2026-for-cios-and-ctos)). This allows for enhanced cross-referencing of information, automated summarization, and more robust data-driven strategic planning ([Source](https://www.tiledb.com/blog/multimodal-ai-models)).\n\nFurthermore, these models are enabling advanced visual agent capabilities. By interpreting screen context and visual elements, multimodal LLMs can debug UI issues, automate complex workflows, and provide intelligent assistance based on what a user sees ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)). This visual reasoning, exemplified by models like Gemini, allows for more intuitive and effective human-computer interaction ([Source](https://storage.googleapis.com/deepmind-media/gemini/gemini_1_report.pdf)).\n\nThe general-purpose visual and language understanding capabilities of multimodal LLMs are enhancing human-AI interaction across various sectors. From optimizing financial analysis in the Finance sector to improving quality control and automation in Manufacturing, these models offer more intuitive and comprehensive AI assistants ([Source](https://www.siliconflow.com/articles/en/best-multimodal-ai-models)). This broad applicability underscores their foundational role in future AI systems.'),
#   (6,
#    '## Overcoming Hurdles and Future Trajectories\n\nAs multimodal LLMs continue their rapid advancement into 2026, several key challenges remain central to their widespread and responsible deployment. Addressing these hurdles is crucial for unlocking their full potential.\n\nEvaluating multimodal performance presents significant complexities due to the diverse data types and intricate interactions. Comprehensive surveys highlight the need for robust evaluation methods, with benchmarks like BenchLMM emerging to assess cross-style visual capabilities and other multimodal understanding tasks ([Source](https://openreview.net/pdf/590fe121615444b1009e27d1798d3649237a7436.pdf)). These evaluations are critical for understanding how models handle nuanced, real-world scenarios.\n\nPotential edge cases and failure modes are a persistent concern. Multimodal inputs can be ambiguous or present conflicting information across modalities, leading to unpredictable outputs. Strategies for robustness involve improving cross-modal alignment and uncertainty quantification to ensure reliable performance even with challenging or contradictory data ([Source](https://aclanthology.org/2024.findings-acl.738.pdf)).\n\nOptimizing performance and managing computational costs remain critical, especially for deployment on edge devices. The resource intensity of multimodal LLMs poses challenges for efficiency and real-time processing in constrained environments ([Source](https://embeddedvisionsummit.com/2024/session/multimodal-llms-at-the-edge-are-we-there-yet/)). Future work focuses on model compression, quantization, and specialized hardware acceleration to enable broader accessibility.\n\nEmerging ethical implications demand careful consideration. Data bias can be amplified across diverse modalities, leading to unfair or inaccurate outcomes. Privacy concerns intensify with sensitive inputs like images, audio, and video. Ensuring the responsible use of advanced generative capabilities, preventing misuse, and establishing transparency are paramount for ethical development and public trust ([Source](https://arxiv.org/abs/2401.13601)).')],
#  'final': "# The State of Multimodal LLMs in 2026\n\n## The Multimodal Revolution: LLMs in 2026\n\nMultimodal Large Language Models (MM-LLMs) represent a fundamental shift in AI, capable of processing and integrating diverse data types beyond just text. These models can simultaneously understand and generate content from text, images, audio, and video, mirroring human perception more closely ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)). This capability allows for richer contextual understanding and more complex reasoning across various inputs ([Source](https://www.datastudios.org/post/google-gemini-multimodal-capabilities-text-images-audio-and-video-support)).\n\nLooking into 2026, Google's forecasts highlight a significant surge in multimodal AI adoption and capabilities ([Source](https://uniathena.com/ai-trends-predictions-possibilities-2025)). This trend is expected to broaden the application landscape for MM-LLMs, making them a pivotal technology across industries ([Source](https://www.tiledb.com/blog/multimodal-ai-models)).\n\nBy integrating multiple modalities, MM-LLMs significantly enhance AI's natural interaction capabilities, moving beyond text-only interfaces. They also deliver more accurate and contextually rich outputs across a wide range of applications, from advanced content generation to complex data analysis and intuitive user interfaces ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)).\n\n## Market Dynamics and Enterprise Integration\n\nThe multimodal AI market is experiencing significant expansion, projected to reach a global size of $3.43 billion in 2026 and an estimated $12.06 billion by 2030 ([Source](https://www.siliconflow.com/articles/en/best-multimodal-ai-models)). This rapid growth is largely driven by increasing enterprise adoption.\n\nEnterprises are integrating multimodal AI to achieve deeper analysis, more accurate predictions, and effective decision-making across their operations ([Source](https://www.tiledb.com/blog/multimodal-ai-models)). This capability to process and synthesize information from diverse modalities (text, image, audio) provides comprehensive insights.\n\nMultimodal AI is actively redefining existing AI applications in various sectors. Industries such as Finance and Manufacturing are seeing transformative changes, leveraging these models for enhanced operational efficiency and innovation ([Source](https://www.usaii.org/ai-insights/how-multimodal-ai-is-redefining-modern-ai-applications)).\n\nFurther enabling this broader deployment are advancements in cost-effective training strategies. These strategies are crucial for reducing operational expenses, making multimodal AI solutions more accessible and scalable for businesses of all sizes ([Source](https://embeddedvisionsummit.com/2024/session/multimodal-llms-at-the-edge-are-we-there-yet/)).\n\n## Leading the Charge: Key Multimodal Models of 2026\n\nThe year 2026 sees a robust landscape of multimodal large language models (MM-LLMs), pushing the boundaries of AI interaction and understanding. These models are defined by their ability to process and generate content across various data types, moving beyond text-only paradigms.\n\nGoogle's Gemini series stands out for its natively multimodal architecture. It can accept a diverse range of inputs—text, images, audio, video, and even code—within a single request, enabling it to cross-reference and reason across these distinct modalities seamlessly ([Source](https://www.datastudios.org/post/google-gemini-multimodal-capabilities-text-images-audio-and-video-support)). This integrated approach allows for complex understanding, such as analyzing a video with an accompanying transcript and images for comprehensive context ([Source](https://www.clarifai.com/blog/gemini-2.5-pro-vs-gpt-5)).\n\nOpenAI's anticipated GPT-5 is expected to further advance multimodal capabilities with a unified ar ...
